# %%
import glob
import pandas as pd

# %%
path = r'E:\Dropbox\Pessoal\Python\SP\rar\descompactados'

# %%
folders = glob.glob(path + "/*")

# %%
arquivos = []
for f in folders:
    file = glob.glob(f + "/*.txt")
    arquivos.append(file)
arquivos = [item for sublist in arquivos for item in sublist]

# %%
dfs=[]
n=1
for file in arquivos:
    print('lendo arquivo {}'.format(file))
    print('lendo arquivo {} de {}'.format(n, len(arquivos)))
    n+=1
    try:
        globals()[file.split('\\')[-2]] =  pd.read_csv(file,sep=';',encoding='latin-1',
                                                   usecols = ['NOME','CARGO','ORGAO','TOTBRU_FINAL','TOTLIQ_FINAL'])
        globals()[file.split('\\')[-2]].rename(columns={'TOTBRU_FINAL': "BRUTO",            
                                                            'TOTLIQ_FINAL':'LIQUIDO'}, inplace=True)
               
        globals()[file.split('\\')[-2]]['ANO'] = file.split('\\')[-2].split('_')[1]
        globals()[file.split('\\')[-2]]['MES'] = file.split('\\')[-2].split('_')[0]
        
        globals()[file.split('\\')[-2]]['BRUTO'] = globals()[file.split('\\')[-2]]\
        ['BRUTO'].str.replace(',','.').astype(float)
        globals()[file.split('\\')[-2]]['LIQUIDO'] = globals()[file.split('\\')[-2]]\
        ['LIQUIDO'].str.replace(',','.').astype(float)
        
    except ValueError:
        
        try:
            globals()[file.split('\\')[-2]] =  pd.read_csv(file,sep=';',encoding='latin-1',
                                                   usecols = ['NOME','CARGO','ORGAO','REMUNERAÇÃO DO MÊS','TOTAL LIQUÍDO (R$)'])
            globals()[file.split('\\')[-2]].rename(columns={'REMUNERAÇÃO DO MÊS': "BRUTO",            
                                                            'TOTAL LIQUÍDO (R$)':'LIQUIDO'}, inplace=True)
            
            globals()[file.split('\\')[-2]]['ANO'] = file.split('\\')[-2].split('_')[1]
            globals()[file.split('\\')[-2]]['MES'] = file.split('\\')[-2].split('_')[0]
            
            globals()[file.split('\\')[-2]]['BRUTO'] = globals()[file.split('\\')[-2]]\
            ['BRUTO'].str.replace(',','.').astype(float)
            globals()[file.split('\\')[-2]]['LIQUIDO'] = globals()[file.split('\\')[-2]]\
            ['LIQUIDO'].str.replace(',','.').astype(float)
            
        except ValueError:
            
            try:
                
                globals()[file.split('\\')[-2]] =  pd.read_csv(file,sep=';',encoding='latin-1',
                                                           usecols = ['NOME','CARGO','ORGÃO','REMUNERAÇÃO DO MÊS','TOTAL LIQUÍDO (R$)'])
                globals()[file.split('\\')[-2]].rename(columns={'REMUNERAÇÃO DO MÊS': "BRUTO",'ORGÃO':'ORGAO',
                                                            'TOTAL LIQUÍDO (R$)':'LIQUIDO'}, inplace=True)
                
                globals()[file.split('\\')[-2]]['ANO'] = file.split('\\')[-2].split('_')[1]
                globals()[file.split('\\')[-2]]['MES'] = file.split('\\')[-2].split('_')[0]
                
                globals()[file.split('\\')[-2]]['BRUTO'] = globals()[file.split('\\')[-2]]\
                ['BRUTO'].str.replace(',','.').astype(float)
                globals()[file.split('\\')[-2]]['LIQUIDO'] = globals()[file.split('\\')[-2]]\
                ['LIQUIDO'].str.replace(',','.').astype(float)
        
            except ValueError:
                
                try:
                    globals()[file.split('\\')[-2]] =  pd.read_csv(file,sep=';',encoding='latin-1',
                                                           usecols = ['NOME','CARGO','ORGAO','TOTBRUTO','TOTLIQ'])
                    globals()[file.split('\\')[-2]].rename(columns={'TOTBRUTO': "BRUTO",
                                                            'TOTLIQ':'LIQUIDO'}, inplace=True)
                    
                    globals()[file.split('\\')[-2]]['ANO'] = file.split('\\')[-2].split('_')[1]
                    globals()[file.split('\\')[-2]]['MES'] = file.split('\\')[-2].split('_')[0]
                    
                    
                    globals()[file.split('\\')[-2]]['BRUTO'] = globals()[file.split('\\')[-2]]\
                    ['BRUTO'].str.replace(',','.').astype(float)
                    globals()[file.split('\\')[-2]]['LIQUIDO'] = globals()[file.split('\\')[-2]]\
                    ['LIQUIDO'].str.replace(',','.').astype(float)
                    
                except ValueError:
                    
                    try:
                    
                        globals()[file.split('\\')[-2]] =  pd.read_csv(file,sep=';',encoding='latin-1',
                                                           usecols = ['NOME','CARGO','ÓRGÃO','REMUNERAÇÃO DO MÊS','TOTAL LIQUÍDO (R$)'])
                        globals()[file.split('\\')[-2]].rename(columns={'REMUNERAÇÃO DO MÊS': "BRUTO",'ÓRGÃO':'ORGAO',
                                                            'TOTAL LIQUÍDO (R$)':'LIQUIDO'}, inplace=True)
                        
                        globals()[file.split('\\')[-2]]['ANO'] = file.split('\\')[-2].split('_')[1]
                        globals()[file.split('\\')[-2]]['MES'] = file.split('\\')[-2].split('_')[0]
                        
                        globals()[file.split('\\')[-2]]['BRUTO'] = globals()[file.split('\\')[-2]]\
                        ['BRUTO'].str.replace(',','.').astype(float)
                        
                        globals()[file.split('\\')[-2]]['LIQUIDO'] = globals()[file.split('\\')[-2]]\
                        ['LIQUIDO'].str.replace(',','.').astype(float)
                        
                    except ValueError:
                        
                        globals()[file.split('\\')[-2]] =  pd.read_csv(file,sep=';',encoding='latin-1',
                                                           usecols = ['NOME','CARGO','ORGAO','TOT_REMUN','TOTLIQ_FINAL'])
                        globals()[file.split('\\')[-2]].rename(columns={'TOT_REMUN': "BRUTO",
                                                            'TOTLIQ_FINAL':'LIQUIDO'}, inplace=True)
                        
                        globals()[file.split('\\')[-2]]['ANO'] = file.split('\\')[-2].split('_')[1]
                        globals()[file.split('\\')[-2]]['MES'] = file.split('\\')[-2].split('_')[0]
                        
                        globals()[file.split('\\')[-2]]['BRUTO'] = globals()[file.split('\\')[-2]]\
                        ['BRUTO'].str.replace(',','.').astype(float)
                        globals()[file.split('\\')[-2]]['LIQUIDO'] = globals()[file.split('\\')[-2]]\
                        ['LIQUIDO'].str.replace(',','.').astype(float)
                
                
                
                
                
    dfs.append(file.split('\\')[-2])
# Out:
# lendo arquivo E:\Dropbox\Pessoal\Python\SP\rar\descompactados\Abril_2013\remuneracao_Abril_2013.txt
# lendo arquivo 1 de 103
# lendo arquivo E:\Dropbox\Pessoal\Python\SP\rar\descompactados\Abril_2014\remuneracao_Abril_2014.txt
# lendo arquivo 2 de 103
# lendo arquivo E:\Dropbox\Pessoal\Python\SP\rar\descompactados\Abril_2015\remuneracao.txt
# lendo arquivo 3 de 103
# lendo arquivo E:\Dropbox\Pessoal\Python\SP\rar\descompactados\Abril_2016\remuneracao.txt
# lendo arquivo 4 de 103
# lendo arquivo E:\Dropbox\Pessoal\Python\SP\rar\descompactados\Abril_2017\Remuneracao.txt
# lendo arquivo 5 de 103
# lendo arquivo E:\Dropbox\Pessoal\Python\SP\rar\descompactados\Abril_2018\Remuneracao_Abril_2018.txt
# lendo arquivo 6 de 103
# lendo arquivo E:\Dropbox\Pessoal\Python\SP\rar\descompactados\Abril_2019\Remuneracao.txt
# lendo arquivo 7 de 103
# lendo arquivo E:\Dropbox\Pessoal\Python\SP\rar\descompactados\Abril_2020\Remuneracao.txt
# lendo arquivo 8 de 103
# ...

# %%
dic1 = {'ADM GERAL':'ADMINISTRACAO GERAL DO ESTADO',
 'AGEM':'AGENCIA METROPOLITANA DA BAIXADA SANTISTA',
 'AGEMCAMP':'AGENCIA METROPOLITANA DE CAMPINAS',
 'AGEMVALE': 'AGENCIA METROPOLITANA DO VALE DO PARAIBA',
 'ARSESP': 'AGENCIA REG.SANEA.ENERGIA E.SP-ARSESP',
 'ARTESP': 'AGENCIA REG.SERV.P.DEL.TRANS.E.SP-ARTESP',
 'CBPM':'CAIXA BENEFICENTE DA POLICIA MILITAR',
 'CDHU': 'CIA.DESENV.HABITAC.URBANO EST. SP-CDHU',
 'CEETEPS':'CENTRO EDUC. TECNOL.PAULA SOUZA-CEETEPS',
 'CESP':'COMPANHIA ENERGETICA DE SAO PAULO-CESP',
 'CETESB':'CIA. AMBIENTAL EST. SP - CETESB',
 'CIA DOCAS':'COMPANHIA DOCAS DE SAO SEBASTIAO',
 'CODASP':'CIA DESENVOLVIMENTO AGRICOLA SP-CODASP',
 'COSESP':'CIA.SEGUROS DO EST. DE SAO PAULO-COSESP',
 'CPOS':'CIA PAULISTA OBRAS E SERVICOS-CPOS',
 'CPP': 'COMPANHIA PAULISTA DE PARCEIRAS-CPP',
 'CPSEC':'CIA.PAULISTA DE SECURITIZACAO-CPSEC',
 'CPTM': 'CIA.PAULISTA DE TRENS METROPOLITANO-CPTM',
 'DAEE':'DEPTO.DE AGUAS E ENERGIA ELETRICA-DAEE',
 'DAESP':'DEPARTAMENTO AEROVIARIO EST. SP-DAESP',
 'DER':'DEPARTAMENTO DE ESTRADAS RODAGEM-DER',
 'DERSA':'DESENVOLVIMENTO RODOVIARIO S/A-DERSA',
 'DESENVOLVE SP':'DESENVOLVE SP -AGEN. DE DESENV. PAULISTA',
 'DETRAN':'DEPARTAMENTO ESTADUAL DE TRANSITO-DETRAN',
 'EMAE':'EMPR METROPOL AGUAS E ENERGIA S/A-EMAE',
 'SDPD':'SECRETARIA EST.DIREITOS PESSOA DEFICIENC',
 'SDS':'SECRETARIA DE DESENVOLVIMENTO SOCIAL',
 'SEADE':'FUNDACAO SISTEMA EST.ANALISE DADOS-SEADE',
 'SEPLAN':'SECRETARIA DE PLANEJAMENTO E GESTAO',
 'SERT':'SECRETARIA EMPREGO E RELACOES TRABALHO',
 'SPPREV':'SAO PAULO PREVIDENCIA-SPPREV',
 'SPPREVCOM':'FUNDACAO PREVIDENCIA COMPLEMENTAR ESTADO',
 'SSP':'SEGURANCA PUBLICA',
 'SUCEN':'SUPERINTENDENCIA DE CONTROLE DE ENDEMIAS',
 'TRANSP. METROP.':'TRANSPORTES METROPOLITANOS',
 'TRANSPORTES':'SECRETARIA DE LOGISTICA E TRANSPORTES',
 'UNIVESP':'FUNDACAO UNIVERSIDADE VIRTUAL DO ESTADO',
 'ZOOLOGICO':'FUNDACAO PARQUE ZOOLOGICO DE SAO PAULO',
 '2911,69': 'ADMINISTRACAO GERAL DO ESTADO',
 'AG.M.V.PAR.LIT.NORTE AGEMVALE': 'AGENCIA METROPOLITANA DO VALE DO PARAIBA',
'AG.MET.SOROCABA AGEMSOROCABA':'AGENCIA METROPOLITANA DE SOROCABA',
'AG.METR.SOROCABA-AGEMSOROCABA': 'AGENCIA METROPOLITANA DE SOROCABA',
"AG.REG.SAN.EN.EST.SP. ARSESP": 'AGENCIA REG.SANEA.ENERGIA E.SP-ARSESP',
"AG.REG.SERV.PUB.EST.SP ARSESP":'AGENCIA REG.SANEA.ENERGIA E.SP-ARSESP',
'AG.REG.SV.P.DEL.TR.E.SP ARTESP' : 'AGENCIA REG.SERV.P.DEL.TRANS.E.SP-ARTESP',
'AG.REG.SV.PUB.DEL.TRANSP.EST.SP ARTESP': 'AGENCIA REG.SERV.P.DEL.TRANS.E.SP-ARTESP',
'AG.REGUL.SERV.PUBL.DEL.TRANSP.SP-ARTESP': 'AGENCIA REG.SERV.P.DEL.TRANS.E.SP-ARTESP',
'AGEMSOROCABA': 'AGENCIA METROPOLITANA DE SOROCABA',
"AGENCIA METROP.B.SANTISTA AGEM": 'AGENCIA METROPOLITANA DA BAIXADA SANTISTA',
'AGENCIA METROPOL.BAIXADA SANTISTA-AGEM':"AGENCIA METROPOLITANA DA BAIXADA SANTISTA",
'AGENCIA METROPOLIT.BAIXADA SANTISTA-AGEM': 'AGENCIA METROPOLITANA DA BAIXADA SANTISTA',
'AGENCIA METROPOLIT.CAMPINAS-AGEMCAMP' : 'AGENCIA METROPOLITANA DE CAMPINAS',
'AGENCIA MET.CAMPINAS AGEMCAMP':'AGENCIA METROPOLITANA DE CAMPINAS',
'AGENCIA METROPOLIT.SOROCABA-AGEMSOROCABA' :'AGENCIA METROPOLITANA DE SOROCABA',
'AGENCIA METROPOLITANA BAIXADA SANTISTA -': 'AGENCIA METROPOLITANA DA BAIXADA SANTISTA',
'FUNDACAO PROCON':'FUNDACAO PROTEC.DEFESA CONSUMIDOR-PROCON',
'FUND.PF.DR.M.P.PIMENTEL-FUNAP':'FUNDACAO PROF.D.MANOEL P.PIMENTEL -FUNAP',
'FUND.PRF.DR.MANOEL PEDRO PIMENTEL-FUNAP':'FUNDACAO PROF.D.MANOEL P.PIMENTEL -FUNAP',
'FUND.PRO-SANGUE-HEMOCENTRO S.P':'FUNDACAO PRO-SANGUE-HEMOCENTRO SAO PAULO',
'FUND.PRO-SANGUE-HEMOCENTRO S.PAULO':'FUNDACAO PRO-SANGUE-HEMOCENTRO SAO PAULO',
'FUNDACAO PROCON':'FUNDACAO PROTEC.DEFESA CONSUMIDOR-PROCON',
'FUND.SIST.EST.ANAL.DADOS SEADE':'FUNDACAO SISTEMA EST.ANALISE DADOS-SEADE',
'FUND.SIST.EST.ANAL.DADOS-SEADE':'FUNDACAO SISTEMA EST.ANALISE DADOS-SEADE',
'FUND.SISTEMA EST.ANALISE DADOS-SEADE':'FUNDACAO SISTEMA EST.ANALISE DADOS-SEADE',
'FUNDACAO SISTEMA ESTADUAL DE ANALISE DE':'FUNDACAO SISTEMA EST.ANALISE DADOS-SEADE',
'FUND.UN.VIRTUAL EST.SP UNIVESP':'FUNDACAO UNIVERSIDADE VIRTUAL DO ESTADO',
'FUND.UNIV.VIRTUAL EST. S.P.-UNIVESP':'FUNDACAO UNIVERSIDADE VIRTUAL DO ESTADO',
'FUND.UNIV.VIRTUAL EST. S.PAULO - UNIVESP':'FUNDACAO UNIVERSIDADE VIRTUAL DO ESTADO',
'H.C.FAC.MED.BOTUCATU-HCFMB':'HOSPITAL CLINICAS FAC.MED.BOTUCATU-HCFMB',
'HOSPITAL DAS CLINICAS FAC.MED.BOTUCATU':'HOSPITAL CLINICAS FAC.MED.BOTUCATU-HCFMB',
'HABITACAO':'SECRETARIA DA HABITACAO',
'HC FAC MEDICINA RIB PRETO USP':'HOSP.CLINICAS FAC.MEDICINA RIB.PRETO-USP',
'HOSPITAL DAS CLINICAS FAC.MED. RIB.PRETO':'HOSP.CLINICAS FAC.MEDICINA RIB.PRETO-USP',
'HCFAMEMA':'HOSP.CLIN.FAC.MED.MARILIA',
'SP.CLIN.FAC.MED.MARILIA-HCFAMEMA' : 'HOSP.CLIN.FAC.MED.MARILIA',
'HCFMM':'HOSP.CLIN.FAC.MED.MARILIA',
'HOSP.CLIN.FAC.MED.MARILIA':'HOSP.CLIN.FAC.MED.MARILIA',
'HOSP.CLIN.FAC.MED.USP-HCFMUSP':'HOSPITAL CLINICAS FACULDADE MEDICINA-USP',
'HOSPITAL DAS CLINICAS FAC.MED. DA USP':'HOSPITAL CLINICAS FACULDADE MEDICINA-USP',
'HOSPITAL DAS CLINICAS FAC.MED.DA USP':'HOSPITAL CLINICAS FACULDADE MEDICINA-USP',
'HOSPITAL DAS CLINICAS FACUL.MEDICINA DE':'HOSPITAL CLINICAS FACULDADE MEDICINA-USP',
'IAMSPE':'INST.ASSIST.MEDICA SERV.PUBLICO-IAMSPE',
'INST.AS.MED.SER.PUB.EST IAMSPE':'INST.ASSIST.MEDICA SERV.PUBLICO-IAMSPE',
'INST.AS.MED.SERV.P.EST. IAMSPE':'INST.ASSIST.MEDICA SERV.PUBLICO-IAMSPE',
'INST.ASS.MED.SER.P.EST.-IAMSPE':'INST.ASSIST.MEDICA SERV.PUBLICO-IAMSPE',
'INST.ASS.MED.SERV.P.EST-IAMSPE':'INST.ASSIST.MEDICA SERV.PUBLICO-IAMSPE',
'INSTITUTO ASSISTENCIA MEDICA AO SERVIDOR':'INST.ASSIST.MEDICA SERV.PUBLICO-IAMSPE',
'INSTITUTO DE ASSISTENCIA MEDICA SERVIDOR':'INST.ASSIST.MEDICA SERV.PUBLICO-IAMSPE',
'INSTIT.ASSIST.MEDICA SERV.PUBLICO-IAMSPE':'INST.ASSIST.MEDICA SERV.PUBLICO-IAMSPE',
'IMPRENSA OFICIAL DO ESTADO S.A.   IMESP':'IMPRENSA OFICIAL DO ESTADO S/A-IMESP',
'IMPR.OFICIAL ESTADO S.A. IMESP':'IMPRENSA OFICIAL DO ESTADO S/A-IMESP',
'INST MEDICINA SOC E CRIMIN S.P. -IMESC':'INST MEDICINA SOC E CRIMIN S.P. -IMESC',
'IMPRENSA OFICIAL DO ESTADO S/A - IMESP':'IMPRENSA OFICIAL DO ESTADO S/A-IMESP',
'INST MED SOC CRIMINO SP- IMESC':'INST MEDICINA SOC E CRIMIN S.P. -IMESC',
'INST.PAGTOS.ESPECIAIS SP-IPESP':'INSTITUTO PAGAMENTOS ESPECIAIS SP- IPESP',
'INST.PAGTOS.ESPECIAIS SP-IPESP':'INSTITUTO PAGAMENTOS ESPECIAIS SP- IPESP',
'INSTITUTO PAGAMENTOS ESPECIAIS SP- IPESP':'INSTITUTO PAGAMENTOS ESPECIAIS SP- IPESP',        
'INST.PESOS MEDID.E.S.P-IPEM/SP':'INST.PESOS MEDIDAS EST.SAO PAULO-IPEM/SP',
'INST.PESQ.TECNOLOGICAS EST.S.P':'INST.PESQUISAS TECN. EST.S.PAULO-IPT',
'INST.PESQU.TECNOLOGICAS EST.SP-S/A-IPT':'INST.PESQUISAS TECN. EST.S.PAULO-IPT',
'JUNTA COMERC.E.S.PAULO-JUCESP':'JUNTA COMERCIAL ESTADO S.P.-JUCESP',
'JUNTA COMERCIAL DO ESTADO DE SAO PAULO-J':'JUNTA COMERCIAL ESTADO S.P.-JUCESP',
'JUSTICA E DEFESA DA CIDADANIA':'SECRETARIA JUSTICA E DEFESA DA CIDADANIA',
'SECRETARIA DE LOGISTICA E TRAN':'SECRETARIA DE LOGISTICA E TRANSPORTES',
'LOGISTICA E TRANSPORTES':'SECRETARIA DE LOGISTICA E TRANSPORTES',
'SECRETARIA DE AGRICULTURA E ABASTECIMENT':'SECRETARIA DE AGRICULTURA ABASTECIMENTO',
'JUSTICA': 'SECRETARIA JUSTICA E DEFESA DA CIDADANIA',
'SECRETARIA JUSTICA E CIDADANIA': 'SECRETARIA JUSTICA E DEFESA DA CIDADANIA',
'SECRETARIA DESENV. REGIONAL':'SECRETARIA DE DESENVOLVIMENTO REGIONAL',
'SECRETARIA LOGIST. TRANSPORTES':'SECRETARIA DE LOGISTICA E TRANSPORTES',
}

# %%
n=1
for df in dfs:
    print('editando arquivo {}'.format(df))
    print('editando arquivo {} de {}'.format(n, len(dfs)))
    n+=1
    globals()[df].replace(dic1, inplace=True)
# Out:
# editando arquivo Abril_2013
# editando arquivo 1 de 103
# editando arquivo Abril_2014
# editando arquivo 2 de 103
# editando arquivo Abril_2015
# editando arquivo 3 de 103
# editando arquivo Abril_2016
# editando arquivo 4 de 103
# editando arquivo Abril_2017
# editando arquivo 5 de 103
# editando arquivo Abril_2018
# editando arquivo 6 de 103
# editando arquivo Abril_2019
# editando arquivo 7 de 103
# editando arquivo Abril_2020
# editando arquivo 8 de 103
# editando arquivo Abril_2021
# editando arquivo 9 de 103
# editando arquivo Agosto_2013
# editando arquivo 10 de 103
# editando arquivo Agosto_2014
# editando arquivo 11 de 103
# editando arquivo Agosto_2015
# editando arquivo 12 de 103
# editando arquivo Agosto_2016
# editando arquivo 13 de 103
# editando arquivo Agosto_2017
# editando arquivo 14 de 103
# editando arquivo Agosto_2018
# editando arquivo 15 de 103
# editando arquivo Agosto_2019
# editando arquivo 16 de 103
# editando arquivo Agosto_2020
# ...

# %%
globals()[dfs[0]][globals()[dfs[0]]['BRUTO']> 0]
# Out:
#                                NOME                                    CARGO  \
# 0           AAIRON TELES DE CAMARGO                   OFICIAL ADMINISTRATIVO
# 1           AAIRON TELES DE CAMARGO                   OFICIAL ADMINISTRATIVO
# 2        AARAN ESTEVAO LIMA BARBOSA                                 2TEN  PM
# 3                 AARAO DE OLIVEIRA                                 MAJ   PM
# 4         AARON DE OLIVEIRA BARBOSA           AGENTE TECNICO ASSIST. A SAUDE
# ...                             ...                                      ...
# 1055549      ZUVIA OSPEDAL DA SILVA  BENEFICIARIO DE SERVIDOR ESTADUAL-IPESP
# 1055550     ZUZILOTE GALDIKS GARDIM             PROFESSOR EDUCACAO BASICA II
# 1055551   ZUZIMEIRE TOSTES DA SILVA             AGENTE DE SERVICOS ESCOLARES
# 1055552    ZVONIMIRO VARVELLO PESUT                                  CHEFE I
# 1055553         ZYSLA LEA SCHNEIDER  BENEFICIARIO DE SERVIDOR ESTADUAL-IPESP
#
# ...

# %%
for df in dfs:
    globals()[df] = globals()[df][globals()[df]['BRUTO']> 0]\
    .groupby(by=['ORGAO','CARGO','ANO','MES'])[['BRUTO','LIQUIDO']].agg(['sum','count'])
    
    globals()[df].drop(globals()[df].columns[len(globals()[df].columns)-1], axis=1, inplace=True)

# %%
for df in dfs:
    globals()[df].to_csv(r'dados/{}.csv'.format(df))
